# %% [markdown]
# # EDA-03 Dealing with Data Quality Problems

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Customers.csv")

# %%
data
# Out:
#      ID      Name  Gender   PO BOX              Email              CNIC  \
# 0   1001       Ali       M  A74000        Ali@gmailcom  42301-4774468-1
# 1   1002     Ahmed       M   74100     Ahmed@gmail.com  42301-4774469-1
# 2   1003      Sara       F   74000      Sara@gmail.com  42301-4774470-1
# 3   1004   Janifer       F   74500   Janifer@gmail.com  42301-4774471-1
# 4   1005     Aslam       M   74300     Aslam@gmail.com  42301-4774472-1
# 5   1006    Jatin        M   74500    Jatin @gmail.com  42301-4774473-1
# 6   1007     Arham       M   75200     Arham@gmail.com  42301-4774474-1
# 7   1008     David       M   75400     David@gmail.com  42301-4774475-1
# 8   1009       NaN       F     NaN              eetert              NaN
# 9   1010     Somro       M   74100   Somro@hotmail.com  42301-4774477-1
# 10  1011      Khan       M   74000    Khan@hotmail.com  42301-4774478-1
# 11  1012     Bilal       M   74500   Bilal@hotmail.com  42301-4774479-1
# 12  1013     Basit       M   74300   Basit@hotmail.com  42301-4774480-1
# 13  1014     Karim       M   74500    Karimhotmail.com  42301-4774481-1
# 14  1015    Kaleem       M   75200  Kaleem@hotmail.com  42301-4774482-1
# 15  1016     Jafer       M   75400   Jafer@hotmail.com  42301-4774483-1
# 16  1017    Junaid       M   74000  Junaid@hotmail.com  42301-4774484-2
# 17  1018       Zia       M   74100     Zia@hotmail.com  42301-4774485-2
# 18  1019      Zaki       M   74000        Zaki@fti.com   42301-474486-2
# 19  1020    Rashid       M   74500      Rashid@fti.com  42301-4774487-2
# 20  1021      Rana       M   74300        Rana@fti.com  42301-4774488-2
# 21  1022      saad       M   74500        saad@fti.com  42301-4774489-2
# 22  1023     Salim       M   75200        Salimfti.com  42301-4774490-2
# 23  1024    Chatin       M    5400      Chatin@fti.com  42301-4774491-2
# 24  1025    Mazhar       M   74500      Mazhar@fti.com   42301-4774492-
# 25  1026     Rafiq       M   75200       Rafiq@fti.com  42301-4774493-2
# 26  1027     Iqbal       M   75400       Iqbal@fti.com  42301-4774494-2
# 27  1028    Farooq       M   74000      Farooq@fti.com  42301-4774495-2
# 28  1029  William        M   74100    William @fti.com  42301-4774496-2
# 29  1030     Jaqob       M   74200       jaqob@fti.com  42301-4774476-2
#
#            DOB  Registered_Age      Mobile       Religion
# 0    12/1/1980              30  3002090485         Islam
# 1   14/02/1986              25  3002090486            NaN
# 2   23/02/2000              15  3002090487            NaN
# 3   16/05/2008               8   300209048            NaN
# 4   17/04/2006               8  3002090489            NaN
# 5   18/03/2004               9  3002090490      Hinduaism
# 6   17/02/2002              12  3002090491            NaN
# 7   19/01/2000              14  3002090492            NaN
# 8   20/12/1997              20  3002090493            NaN
# 9   21/11/1995              23  3002090494            NaN
# 10  22/10/1993              20  3002090495            NaN
# 11  23/09/1991              23  3002090496            NaN
# 12  24/08/1989              25  3002090497            NaN
# 13  26/07/1987              25  3002090498            NaN
# 14  26/06/1985              30  3002090499         Islam
# 15  28/05/1983              31  3002090500            NaN
# 16  28/04/1981              32  3002090501            NaN
# 17  30/03/1979              30  3002090502            NaN
# 18  28/02/1977              35  3002090503            NaN
# 19  30/01/1975              30  3002090504            NaN
# 20  15/05/2004              14  3002090505            NaN
# 21  16/05/2004              13  3002090506            NaN
# 22  17/05/2004              13  3002090507            NaN
# 23    3/2/1990              23  3002090508         Islam
# 24  26/07/1987              25     3002090            NaN
# 25  26/06/1985              26   ABBBassas            NaN
# 26  28/05/1983              32  3002090511            NaN
# 27  21/11/1995              21  3002090512            NaN
# 28  22/10/1993              20  3002090513  Christianity
# 29  23/10/1993              20  3362090878  Christianity

# %%
data.shape
# Out:
# (30, 10)

# %%
data.dtypes
# Out:
# ID                 int64
# Name              object
# Gender            object
# PO BOX            object
# Email             object
# CNIC              object
# DOB               object
# Registered_Age     int64
# Mobile            object
# Religion          object
# dtype: object

# %% [markdown]
# ### 1.Renaming Columns

# %%
data.columns
# Out:
# Index(['ID ', 'Name ', 'Gender ', 'PO BOX', 'Email ', 'CNIC', 'DOB',
#        'Registered_Age', 'Mobile', 'Religion'],
#       dtype='object')

# %%
data.rename(columns={'ID ':'ID','Name ':'Name','Gender ':'Gender','PO BOX':'POBOX','Email ':'Email'},inplace=True)

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Gender', 'POBOX', 'Email', 'CNIC', 'DOB',
#        'Registered_Age', 'Mobile', 'Religion'],
#       dtype='object')

# %% [markdown]
# ### 2.Checking for Null Values

# %%
data.isnull().sum()
# Out:
# ID                 0
# Name               1
# Gender             0
# POBOX              1
# Email              0
# CNIC               1
# DOB                0
# Registered_Age     0
# Mobile             0
# Religion          24
# dtype: int64

# %% [markdown]
# #### a) Drop all coulmns where there are more than 70% missing values

# %%
data.dropna(axis=1, thresh=0.70*len(data),inplace=True)

# %%
data.head()
# Out:
#      ID     Name Gender   POBOX              Email             CNIC  \
# 0  1001      Ali      M  A74000       Ali@gmailcom  42301-4774468-1
# 1  1002    Ahmed      M   74100    Ahmed@gmail.com  42301-4774469-1
# 2  1003     Sara      F   74000     Sara@gmail.com  42301-4774470-1
# 3  1004  Janifer      F   74500  Janifer@gmail.com  42301-4774471-1
# 4  1005    Aslam      M   74300    Aslam@gmail.com  42301-4774472-1
#
#           DOB  Registered_Age      Mobile
# 0   12/1/1980              30  3002090485
# 1  14/02/1986              25  3002090486
# 2  23/02/2000              15  3002090487
# 3  16/05/2008               8   300209048
# 4  17/04/2006               8  3002090489

# %%
data.shape
# Out:
# (30, 9)

# %% [markdown]
# #### b) lets define a subset of columns and drop records if all the values are NaN

# %%
data.dropna(how='all', subset=['Email','CNIC','POBOX','Mobile'],inplace=True)

# %%
data.shape
# Out:
# (30, 9)

# %% [markdown]
# #### c) lets define a subset of columns and drop records if there is any NaN value

# %%
data.dropna(how='any', subset=['Email','CNIC','POBOX','Mobile'], inplace=True)

# %%
data.shape
# Out:
# (29, 9)

# %%
data.head()
# Out:
#      ID     Name Gender   POBOX              Email             CNIC  \
# 0  1001      Ali      M  A74000       Ali@gmailcom  42301-4774468-1
# 1  1002    Ahmed      M   74100    Ahmed@gmail.com  42301-4774469-1
# 2  1003     Sara      F   74000     Sara@gmail.com  42301-4774470-1
# 3  1004  Janifer      F   74500  Janifer@gmail.com  42301-4774471-1
# 4  1005    Aslam      M   74300    Aslam@gmail.com  42301-4774472-1
#
#           DOB  Registered_Age      Mobile
# 0   12/1/1980              30  3002090485
# 1  14/02/1986              25  3002090486
# 2  23/02/2000              15  3002090487
# 3  16/05/2008               8   300209048
# 4  17/04/2006               8  3002090489

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#      ID     Name Gender   POBOX              Email             CNIC  \
# 0  1001      Ali      M  A74000       Ali@gmailcom  42301-4774468-1
# 1  1002    Ahmed      M   74100    Ahmed@gmail.com  42301-4774469-1
# 2  1003     Sara      F   74000     Sara@gmail.com  42301-4774470-1
# 3  1004  Janifer      F   74500  Janifer@gmail.com  42301-4774471-1
# 4  1005    Aslam      M   74300    Aslam@gmail.com  42301-4774472-1
#
#           DOB  Registered_Age      Mobile
# 0   12/1/1980              30  3002090485
# 1  14/02/1986              25  3002090486
# 2  23/02/2000              15  3002090487
# 3  16/05/2008               8   300209048
# 4  17/04/2006               8  3002090489

# %%
data.isnull().sum()
# Out:
# ID                0
# Name              0
# Gender            0
# POBOX             0
# Email             0
# CNIC              0
# DOB               0
# Registered_Age    0
# Mobile            0
# dtype: int64

# %% [markdown]
# # 3. Changing Data Types

# %%
data.dtypes
# Out:
# ID                 int64
# Name              object
# Gender            object
# POBOX             object
# Email             object
# CNIC              object
# DOB               object
# Registered_Age     int64
# Mobile            object
# dtype: object

# %% [markdown]
# Changing Data Types

# %%
data.head()
# Out:
#      ID     Name Gender   POBOX              Email             CNIC  \
# 0  1001      Ali      M  A74000       Ali@gmailcom  42301-4774468-1
# 1  1002    Ahmed      M   74100    Ahmed@gmail.com  42301-4774469-1
# 2  1003     Sara      F   74000     Sara@gmail.com  42301-4774470-1
# 3  1004  Janifer      F   74500  Janifer@gmail.com  42301-4774471-1
# 4  1005    Aslam      M   74300    Aslam@gmail.com  42301-4774472-1
#
#           DOB  Registered_Age      Mobile
# 0   12/1/1980              30  3002090485
# 1  14/02/1986              25  3002090486
# 2  23/02/2000              15  3002090487
# 3  16/05/2008               8   300209048
# 4  17/04/2006               8  3002090489

# %%
data['ID']=data['ID'].astype(int)
data['DOB']=pd.to_datetime (data['DOB'])

# %%
data.dtypes
# Out:
# ID                         int32
# Name                      object
# Gender                    object
# POBOX                     object
# Email                     object
# CNIC                      object
# DOB               datetime64[ns]
# Registered_Age             int64
# Mobile                    object
# dtype: object

# %% [markdown]
# ### 4.Dealing with Incorrect Data

# %% [markdown]
# a) Validating POBOX ( Length of POBOX should be 5 and it should not contain any alphabet)

# %%
cnt=0
for row in data['POBOX']:
    if(len(str(row))!=5)or (any(c.isalpha()for c in row)):
        data.loc[cnt,'POBOX']=np.nan
    cnt+=1

# %%
c='?'
c.isalpha()
# Out:
# False

# %%
data.head()
# Out:
#      ID     Name Gender  POBOX              Email             CNIC        DOB  \
# 0  1001      Ali      M    NaN       Ali@gmailcom  42301-4774468-1 1980-12-01
# 1  1002    Ahmed      M  74100    Ahmed@gmail.com  42301-4774469-1 1986-02-14
# 2  1003     Sara      F  74000     Sara@gmail.com  42301-4774470-1 2000-02-23
# 3  1004  Janifer      F  74500  Janifer@gmail.com  42301-4774471-1 2008-05-16
# 4  1005    Aslam      M  74300    Aslam@gmail.com  42301-4774472-1 2006-04-17
#
#    Registered_Age      Mobile
# 0              30  3002090485
# 1              25  3002090486
# 2              15  3002090487
# 3               8   300209048
# 4               8  3002090489

# %% [markdown]
# b) Validating Mobile

# %%
cnt=0
for row in data['Mobile']:
    if(len(str(row))>15)or (len(str(row))<10) or (any(c.isalpha()for c in row)):
        data.loc[cnt,'Mobile']=np.nan
    else:
        pass
    cnt+=1

# %%
data
# Out:
#       ID      Name Gender  POBOX               Email             CNIC  \
# 0   1001       Ali      M    NaN        Ali@gmailcom  42301-4774468-1
# 1   1002     Ahmed      M  74100     Ahmed@gmail.com  42301-4774469-1
# 2   1003      Sara      F  74000      Sara@gmail.com  42301-4774470-1
# 3   1004   Janifer      F  74500   Janifer@gmail.com  42301-4774471-1
# 4   1005     Aslam      M  74300     Aslam@gmail.com  42301-4774472-1
# 5   1006    Jatin       M  74500    Jatin @gmail.com  42301-4774473-1
# 6   1007     Arham      M  75200     Arham@gmail.com  42301-4774474-1
# 7   1008     David      M  75400     David@gmail.com  42301-4774475-1
# 8   1010     Somro      M  74100   Somro@hotmail.com  42301-4774477-1
# 9   1011      Khan      M  74000    Khan@hotmail.com  42301-4774478-1
# 10  1012     Bilal      M  74500   Bilal@hotmail.com  42301-4774479-1
# 11  1013     Basit      M  74300   Basit@hotmail.com  42301-4774480-1
# 12  1014     Karim      M  74500    Karimhotmail.com  42301-4774481-1
# 13  1015    Kaleem      M  75200  Kaleem@hotmail.com  42301-4774482-1
# 14  1016     Jafer      M  75400   Jafer@hotmail.com  42301-4774483-1
# 15  1017    Junaid      M  74000  Junaid@hotmail.com  42301-4774484-2
# 16  1018       Zia      M  74100     Zia@hotmail.com  42301-4774485-2
# 17  1019      Zaki      M  74000        Zaki@fti.com   42301-474486-2
# 18  1020    Rashid      M  74500      Rashid@fti.com  42301-4774487-2
# 19  1021      Rana      M  74300        Rana@fti.com  42301-4774488-2
# 20  1022      saad      M  74500        saad@fti.com  42301-4774489-2
# 21  1023     Salim      M  75200        Salimfti.com  42301-4774490-2
# 22  1024    Chatin      M    NaN      Chatin@fti.com  42301-4774491-2
# 23  1025    Mazhar      M  74500      Mazhar@fti.com   42301-4774492-
# 24  1026     Rafiq      M  75200       Rafiq@fti.com  42301-4774493-2
# 25  1027     Iqbal      M  75400       Iqbal@fti.com  42301-4774494-2
# 26  1028    Farooq      M  74000      Farooq@fti.com  42301-4774495-2
# 27  1029  William       M  74100    William @fti.com  42301-4774496-2
# 28  1030     Jaqob      M  74200       jaqob@fti.com  42301-4774476-2
#
#           DOB  Registered_Age      Mobile
# 0  1980-12-01              30  3002090485
# 1  1986-02-14              25  3002090486
# 2  2000-02-23              15  3002090487
# 3  2008-05-16               8         NaN
# 4  2006-04-17               8  3002090489
# 5  2004-03-18               9  3002090490
# 6  2002-02-17              12  3002090491
# 7  2000-01-19              14  3002090492
# 8  1995-11-21              23  3002090494
# 9  1993-10-22              20  3002090495
# 10 1991-09-23              23  3002090496
# 11 1989-08-24              25  3002090497
# 12 1987-07-26              25  3002090498
# 13 1985-06-26              30  3002090499
# 14 1983-05-28              31  3002090500
# 15 1981-04-28              32  3002090501
# 16 1979-03-30              30  3002090502
# 17 1977-02-28              35  3002090503
# 18 1975-01-30              30  3002090504
# 19 2004-05-15              14  3002090505
# 20 2004-05-16              13  3002090506
# 21 2004-05-17              13  3002090507
# 22 1990-03-02              23  3002090508
# 23 1987-07-26              25         NaN
# 24 1985-06-26              26         NaN
# 25 1983-05-28              32  3002090511
# 26 1995-11-21              21  3002090512
# 27 1993-10-22              20  3002090513
# 28 1993-10-23              20  3362090878

# %% [markdown]
# c) Validating Email

# %% [markdown]
# Validating Email Using Regular Expressions

# %%
import re
regexp = re.compile ("[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}")
cnt=0
for row in data['Email']:
    if re.search(regexp,row):  
        print(cnt, " " , row, "  ",  "valid Email Address")
    else:   
        print(cnt, row, "Invalid Email Address")
    cnt+=1
# Out:
# 0 Ali@gmailcom Invalid Email Address
# 1   Ahmed@gmail.com    valid Email Address
# 2   Sara@gmail.com    valid Email Address
# 3   Janifer@gmail.com    valid Email Address
# 4   Aslam@gmail.com    valid Email Address
# 5 Jatin @gmail.com Invalid Email Address
# 6   Arham@gmail.com    valid Email Address
# 7   David@gmail.com    valid Email Address
# 8   Somro@hotmail.com    valid Email Address
# 9   Khan@hotmail.com    valid Email Address
# 10   Bilal@hotmail.com    valid Email Address
# 11   Basit@hotmail.com    valid Email Address
# 12 Karimhotmail.com Invalid Email Address
# 13   Kaleem@hotmail.com    valid Email Address
# 14   Jafer@hotmail.com    valid Email Address
# 15   Junaid@hotmail.com    valid Email Address
# 16   Zia@hotmail.com    valid Email Address
# 17   Zaki@fti.com    valid Email Address
# 18   Rashid@fti.com    valid Email Address
# 19   Rana@fti.com    valid Email Address
# 20   saad@fti.com    valid Email Address
# 21 Salimfti.com Invalid Email Address
# 22   Chatin@fti.com    valid Email Address
# 23   Mazhar@fti.com    valid Email Address
# 24   Rafiq@fti.com    valid Email Address
# 25   Iqbal@fti.com    valid Email Address
# 26   Farooq@fti.com    valid Email Address
# 27 William @fti.com Invalid Email Address
# 28   jaqob@fti.com    valid Email Address

# %%
import re
regexp = re.compile ("[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}")
cnt=0
for row in data['Email']:
    if re.search(regexp,row):  
        pass
    else:   
        data.loc[cnt, 'Email']=np.nan
    cnt+=1

# %%
data
# Out:
#       ID      Name Gender  POBOX               Email             CNIC  \
# 0   1001       Ali      M    NaN                 NaN  42301-4774468-1
# 1   1002     Ahmed      M  74100     Ahmed@gmail.com  42301-4774469-1
# 2   1003      Sara      F  74000      Sara@gmail.com  42301-4774470-1
# 3   1004   Janifer      F  74500   Janifer@gmail.com  42301-4774471-1
# 4   1005     Aslam      M  74300     Aslam@gmail.com  42301-4774472-1
# 5   1006    Jatin       M  74500                 NaN  42301-4774473-1
# 6   1007     Arham      M  75200     Arham@gmail.com  42301-4774474-1
# 7   1008     David      M  75400     David@gmail.com  42301-4774475-1
# 8   1010     Somro      M  74100   Somro@hotmail.com  42301-4774477-1
# 9   1011      Khan      M  74000    Khan@hotmail.com  42301-4774478-1
# 10  1012     Bilal      M  74500   Bilal@hotmail.com  42301-4774479-1
# 11  1013     Basit      M  74300   Basit@hotmail.com  42301-4774480-1
# 12  1014     Karim      M  74500                 NaN  42301-4774481-1
# 13  1015    Kaleem      M  75200  Kaleem@hotmail.com  42301-4774482-1
# 14  1016     Jafer      M  75400   Jafer@hotmail.com  42301-4774483-1
# 15  1017    Junaid      M  74000  Junaid@hotmail.com  42301-4774484-2
# 16  1018       Zia      M  74100     Zia@hotmail.com  42301-4774485-2
# 17  1019      Zaki      M  74000        Zaki@fti.com   42301-474486-2
# 18  1020    Rashid      M  74500      Rashid@fti.com  42301-4774487-2
# 19  1021      Rana      M  74300        Rana@fti.com  42301-4774488-2
# 20  1022      saad      M  74500        saad@fti.com  42301-4774489-2
# 21  1023     Salim      M  75200                 NaN  42301-4774490-2
# 22  1024    Chatin      M    NaN      Chatin@fti.com  42301-4774491-2
# 23  1025    Mazhar      M  74500      Mazhar@fti.com   42301-4774492-
# 24  1026     Rafiq      M  75200       Rafiq@fti.com  42301-4774493-2
# 25  1027     Iqbal      M  75400       Iqbal@fti.com  42301-4774494-2
# 26  1028    Farooq      M  74000      Farooq@fti.com  42301-4774495-2
# 27  1029  William       M  74100                 NaN  42301-4774496-2
# 28  1030     Jaqob      M  74200       jaqob@fti.com  42301-4774476-2
#
#           DOB  Registered_Age      Mobile
# 0  1980-12-01              30  3002090485
# 1  1986-02-14              25  3002090486
# 2  2000-02-23              15  3002090487
# 3  2008-05-16               8         NaN
# 4  2006-04-17               8  3002090489
# 5  2004-03-18               9  3002090490
# 6  2002-02-17              12  3002090491
# 7  2000-01-19              14  3002090492
# 8  1995-11-21              23  3002090494
# 9  1993-10-22              20  3002090495
# 10 1991-09-23              23  3002090496
# 11 1989-08-24              25  3002090497
# 12 1987-07-26              25  3002090498
# 13 1985-06-26              30  3002090499
# 14 1983-05-28              31  3002090500
# 15 1981-04-28              32  3002090501
# 16 1979-03-30              30  3002090502
# 17 1977-02-28              35  3002090503
# 18 1975-01-30              30  3002090504
# 19 2004-05-15              14  3002090505
# 20 2004-05-16              13  3002090506
# 21 2004-05-17              13  3002090507
# 22 1990-03-02              23  3002090508
# 23 1987-07-26              25         NaN
# 24 1985-06-26              26         NaN
# 25 1983-05-28              32  3002090511
# 26 1995-11-21              21  3002090512
# 27 1993-10-22              20  3002090513
# 28 1993-10-23              20  3362090878

# %% [markdown]
# Validating CNIC

# %%
regexp = re.compile ("^[0-9+]{5}-[0-9+]{7}-[0-9]{1}$")
cnt=0
for row in data['CNIC']:
    if re.search(regexp, row):  
        pass
    else:  
        data.loc[cnt, 'CNIC']=np.nan
    cnt+=1

# %%
data
# Out:
#       ID      Name Gender  POBOX               Email             CNIC  \
# 0   1001       Ali      M    NaN                 NaN  42301-4774468-1
# 1   1002     Ahmed      M  74100     Ahmed@gmail.com  42301-4774469-1
# 2   1003      Sara      F  74000      Sara@gmail.com  42301-4774470-1
# 3   1004   Janifer      F  74500   Janifer@gmail.com  42301-4774471-1
# 4   1005     Aslam      M  74300     Aslam@gmail.com  42301-4774472-1
# 5   1006    Jatin       M  74500                 NaN  42301-4774473-1
# 6   1007     Arham      M  75200     Arham@gmail.com  42301-4774474-1
# 7   1008     David      M  75400     David@gmail.com  42301-4774475-1
# 8   1010     Somro      M  74100   Somro@hotmail.com  42301-4774477-1
# 9   1011      Khan      M  74000    Khan@hotmail.com  42301-4774478-1
# 10  1012     Bilal      M  74500   Bilal@hotmail.com  42301-4774479-1
# 11  1013     Basit      M  74300   Basit@hotmail.com  42301-4774480-1
# 12  1014     Karim      M  74500                 NaN  42301-4774481-1
# 13  1015    Kaleem      M  75200  Kaleem@hotmail.com  42301-4774482-1
# 14  1016     Jafer      M  75400   Jafer@hotmail.com  42301-4774483-1
# 15  1017    Junaid      M  74000  Junaid@hotmail.com  42301-4774484-2
# 16  1018       Zia      M  74100     Zia@hotmail.com  42301-4774485-2
# 17  1019      Zaki      M  74000        Zaki@fti.com              NaN
# 18  1020    Rashid      M  74500      Rashid@fti.com  42301-4774487-2
# 19  1021      Rana      M  74300        Rana@fti.com  42301-4774488-2
# 20  1022      saad      M  74500        saad@fti.com  42301-4774489-2
# 21  1023     Salim      M  75200                 NaN  42301-4774490-2
# 22  1024    Chatin      M    NaN      Chatin@fti.com  42301-4774491-2
# 23  1025    Mazhar      M  74500      Mazhar@fti.com              NaN
# 24  1026     Rafiq      M  75200       Rafiq@fti.com  42301-4774493-2
# 25  1027     Iqbal      M  75400       Iqbal@fti.com  42301-4774494-2
# 26  1028    Farooq      M  74000      Farooq@fti.com  42301-4774495-2
# 27  1029  William       M  74100                 NaN  42301-4774496-2
# 28  1030     Jaqob      M  74200       jaqob@fti.com  42301-4774476-2
#
#           DOB  Registered_Age      Mobile
# 0  1980-12-01              30  3002090485
# 1  1986-02-14              25  3002090486
# 2  2000-02-23              15  3002090487
# 3  2008-05-16               8         NaN
# 4  2006-04-17               8  3002090489
# 5  2004-03-18               9  3002090490
# 6  2002-02-17              12  3002090491
# 7  2000-01-19              14  3002090492
# 8  1995-11-21              23  3002090494
# 9  1993-10-22              20  3002090495
# 10 1991-09-23              23  3002090496
# 11 1989-08-24              25  3002090497
# 12 1987-07-26              25  3002090498
# 13 1985-06-26              30  3002090499
# 14 1983-05-28              31  3002090500
# 15 1981-04-28              32  3002090501
# 16 1979-03-30              30  3002090502
# 17 1977-02-28              35  3002090503
# 18 1975-01-30              30  3002090504
# 19 2004-05-15              14  3002090505
# 20 2004-05-16              13  3002090506
# 21 2004-05-17              13  3002090507
# 22 1990-03-02              23  3002090508
# 23 1987-07-26              25         NaN
# 24 1985-06-26              26         NaN
# 25 1983-05-28              32  3002090511
# 26 1995-11-21              21  3002090512
# 27 1993-10-22              20  3002090513
# 28 1993-10-23              20  3362090878

# %% [markdown]
# ### 5.Handling Outdated Data

# %%
data.head()
# Out:
#      ID     Name Gender  POBOX              Email             CNIC        DOB  \
# 0  1001      Ali      M    NaN                NaN  42301-4774468-1 1980-12-01
# 1  1002    Ahmed      M  74100    Ahmed@gmail.com  42301-4774469-1 1986-02-14
# 2  1003     Sara      F  74000     Sara@gmail.com  42301-4774470-1 2000-02-23
# 3  1004  Janifer      F  74500  Janifer@gmail.com  42301-4774471-1 2008-05-16
# 4  1005    Aslam      M  74300    Aslam@gmail.com  42301-4774472-1 2006-04-17
#
#    Registered_Age      Mobile
# 0              30  3002090485
# 1              25  3002090486
# 2              15  3002090487
# 3               8         NaN
# 4               8  3002090489

# %% [markdown]
# #### a) Create a new Feature

# %%
data ['DOB_Year'] = data['DOB'].dt.year

# %%
data.head()
# Out:
#      ID     Name Gender  POBOX              Email             CNIC        DOB  \
# 0  1001      Ali      M    NaN                NaN  42301-4774468-1 1980-12-01
# 1  1002    Ahmed      M  74100    Ahmed@gmail.com  42301-4774469-1 1986-02-14
# 2  1003     Sara      F  74000     Sara@gmail.com  42301-4774470-1 2000-02-23
# 3  1004  Janifer      F  74500  Janifer@gmail.com  42301-4774471-1 2008-05-16
# 4  1005    Aslam      M  74300    Aslam@gmail.com  42301-4774472-1 2006-04-17
#
#    Registered_Age      Mobile  DOB_Year
# 0              30  3002090485      1980
# 1              25  3002090486      1986
# 2              15  3002090487      2000
# 3               8         NaN      2008
# 4               8  3002090489      2006

# %% [markdown]
# #### 2. Create another feature as Age_Updated and compute current age

# %%
now = pd.to_datetime('today')
now.year
# Out:
# 2021

# %%
data['Age_Updated']=now.year-data['DOB_Year']

# %%
data.head()
# Out:
#      ID     Name Gender  POBOX              Email             CNIC        DOB  \
# 0  1001      Ali      M    NaN                NaN  42301-4774468-1 1980-12-01
# 1  1002    Ahmed      M  74100    Ahmed@gmail.com  42301-4774469-1 1986-02-14
# 2  1003     Sara      F  74000     Sara@gmail.com  42301-4774470-1 2000-02-23
# 3  1004  Janifer      F  74500  Janifer@gmail.com  42301-4774471-1 2008-05-16
# 4  1005    Aslam      M  74300    Aslam@gmail.com  42301-4774472-1 2006-04-17
#
#    Registered_Age      Mobile  DOB_Year  Age_Updated
# 0              30  3002090485      1980           41
# 1              25  3002090486      1986           35
# 2              15  3002090487      2000           21
# 3               8         NaN      2008           13
# 4               8  3002090489      2006           15

# %% [markdown]
# #### 3.Delete Unnecessary Columns

# %%
del data['DOB_Year']

# %% [markdown]
# #### 4. Delete Missing values

# %%
data.isnull().sum()
# Out:
# ID                0
# Name              0
# Gender            0
# POBOX             2
# Email             5
# CNIC              2
# DOB               0
# Registered_Age    0
# Mobile            3
# Age_Updated       0
# dtype: int64

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data.shape
# Out:
# (19, 10)

# %%
data.isnull().sum()
# Out:
# ID                0
# Name              0
# Gender            0
# POBOX             0
# Email             0
# CNIC              0
# DOB               0
# Registered_Age    0
# Mobile            0
# Age_Updated       0
# dtype: int64

# %%
data
# Out:
#       ID    Name Gender  POBOX               Email             CNIC  \
# 0   1002   Ahmed      M  74100     Ahmed@gmail.com  42301-4774469-1
# 1   1003    Sara      F  74000      Sara@gmail.com  42301-4774470-1
# 2   1005   Aslam      M  74300     Aslam@gmail.com  42301-4774472-1
# 3   1007   Arham      M  75200     Arham@gmail.com  42301-4774474-1
# 4   1008   David      M  75400     David@gmail.com  42301-4774475-1
# 5   1010   Somro      M  74100   Somro@hotmail.com  42301-4774477-1
# 6   1011    Khan      M  74000    Khan@hotmail.com  42301-4774478-1
# 7   1012   Bilal      M  74500   Bilal@hotmail.com  42301-4774479-1
# 8   1013   Basit      M  74300   Basit@hotmail.com  42301-4774480-1
# 9   1015  Kaleem      M  75200  Kaleem@hotmail.com  42301-4774482-1
# 10  1016   Jafer      M  75400   Jafer@hotmail.com  42301-4774483-1
# 11  1017  Junaid      M  74000  Junaid@hotmail.com  42301-4774484-2
# 12  1018     Zia      M  74100     Zia@hotmail.com  42301-4774485-2
# 13  1020  Rashid      M  74500      Rashid@fti.com  42301-4774487-2
# 14  1021    Rana      M  74300        Rana@fti.com  42301-4774488-2
# 15  1022    saad      M  74500        saad@fti.com  42301-4774489-2
# 16  1027   Iqbal      M  75400       Iqbal@fti.com  42301-4774494-2
# 17  1028  Farooq      M  74000      Farooq@fti.com  42301-4774495-2
# 18  1030   Jaqob      M  74200       jaqob@fti.com  42301-4774476-2
#
#           DOB  Registered_Age      Mobile  Age_Updated
# 0  1986-02-14              25  3002090486           34
# 1  2000-02-23              15  3002090487           20
# 2  2006-04-17               8  3002090489           14
# 3  2002-02-17              12  3002090491           18
# 4  2000-01-19              14  3002090492           20
# 5  1995-11-21              23  3002090494           25
# 6  1993-10-22              20  3002090495           27
# 7  1991-09-23              23  3002090496           29
# 8  1989-08-24              25  3002090497           31
# 9  1985-06-26              30  3002090499           35
# 10 1983-05-28              31  3002090500           37
# 11 1981-04-28              32  3002090501           39
# 12 1979-03-30              30  3002090502           41
# 13 1975-01-30              30  3002090504           45
# 14 2004-05-15              14  3002090505           16
# 15 2004-05-16              13  3002090506           16
# 16 1983-05-28              32  3002090511           37
# 17 1995-11-21              21  3002090512           25
# 18 1993-10-23              20  3362090878           27

# %% [markdown]
# ### 6. Saving the dataframe as a CSV

# %%
data.to_csv("cleaned.csv", index=False)
